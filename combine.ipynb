# %%
import pandas as pd
import sys
import os

# %%
clean_hydro_data = pd.read_csv("valid_Data/hydrometric.csv")
clean_weather_data = pd.read_csv("valid_Data/weather.csv")

# %%
clean_hydro_data
# Out:
#              Date Station ID                      Station Name Province  \
# 0      2013-01-01    08HB006      PUNTLEDGE RIVER AT COURTENAY       BC
# 1      2013-01-02    08HB006      PUNTLEDGE RIVER AT COURTENAY       BC
# 2      2013-01-03    08HB006      PUNTLEDGE RIVER AT COURTENAY       BC
# 3      2013-01-04    08HB006      PUNTLEDGE RIVER AT COURTENAY       BC
# 4      2013-01-05    08HB006      PUNTLEDGE RIVER AT COURTENAY       BC
# ...           ...        ...                               ...      ...
# 32131  2023-12-27    08NH118  DUNCAN RIVER BELOW LARDEAU RIVER       BC
# 32132  2023-12-28    08NH118  DUNCAN RIVER BELOW LARDEAU RIVER       BC
# 32133  2023-12-29    08NH118  DUNCAN RIVER BELOW LARDEAU RIVER       BC
# 32134  2023-12-30    08NH118  DUNCAN RIVER BELOW LARDEAU RIVER       BC
# 32135  2023-12-31    08NH118  DUNCAN RIVER BELOW LARDEAU RIVER       BC
#
#        Latitude  Longitude  Daily Discharge SYM1  Daily Water Level SYM2  \
# ...

# %%
clean_weather_data
# Out:
#                  Station Name   Latitude   Longitude                 Date  \
# 0            CAMPBELL RIVER A  49.951944 -125.273056  2013-01-01 00:00:00
# 1            CAMPBELL RIVER A  49.951944 -125.273056  2013-01-02 00:00:00
# 2            CAMPBELL RIVER A  49.951944 -125.273056  2013-01-03 00:00:00
# 3            CAMPBELL RIVER A  49.951944 -125.273056  2013-01-04 00:00:00
# 4            CAMPBELL RIVER A  49.951944 -125.273056  2013-01-05 00:00:00
# ...                       ...        ...         ...                  ...
# 20379  QUINSAM RIVER HATCHERY  50.016111 -125.303889  2023-12-27 00:00:00
# 20380  QUINSAM RIVER HATCHERY  50.016111 -125.303889  2023-12-28 00:00:00
# 20381  QUINSAM RIVER HATCHERY  50.016111 -125.303889  2023-12-29 00:00:00
# 20382  QUINSAM RIVER HATCHERY  50.016111 -125.303889  2023-12-30 00:00:00
# 20383  QUINSAM RIVER HATCHERY  50.016111 -125.303889  2023-12-31 00:00:00
#
#        MIN_TEMPERATURE  MAX_TEMPERATURE  MEAN_TEMPERATURE  \
# ...

# %%
clean_hydro_data[clean_hydro_data["match key"] == 3]
# Out:
#              Date Station ID                      Station Name Province  \
# 12051  2013-01-01    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 12052  2013-01-02    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 12053  2013-01-03    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 12054  2013-01-04    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 12055  2013-01-05    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# ...           ...        ...                               ...      ...
# 16063  2023-12-27    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 16064  2023-12-28    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 16065  2023-12-29    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 16066  2023-12-30    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
# 16067  2023-12-31    08HD011  OYSTER RIVER BELOW WOODHUS CREEK       BC
#
#        Latitude  Longitude  Daily Discharge SYM1  Daily Water Level SYM2  \
# ...

# %%
clean_weather_data[clean_weather_data["match key"] == 3]
# Out:
#           Station Name   Latitude   Longitude                 Date  \
# 0     CAMPBELL RIVER A  49.951944 -125.273056  2013-01-01 00:00:00
# 1     CAMPBELL RIVER A  49.951944 -125.273056  2013-01-02 00:00:00
# 2     CAMPBELL RIVER A  49.951944 -125.273056  2013-01-03 00:00:00
# 3     CAMPBELL RIVER A  49.951944 -125.273056  2013-01-04 00:00:00
# 4     CAMPBELL RIVER A  49.951944 -125.273056  2013-01-05 00:00:00
# ...                ...        ...         ...                  ...
# 3931  CAMPBELL RIVER A  49.951944 -125.273056  2023-12-27 00:00:00
# 3932  CAMPBELL RIVER A  49.951944 -125.273056  2023-12-28 00:00:00
# 3933  CAMPBELL RIVER A  49.951944 -125.273056  2023-12-29 00:00:00
# 3934  CAMPBELL RIVER A  49.951944 -125.273056  2023-12-30 00:00:00
# 3935  CAMPBELL RIVER A  49.951944 -125.273056  2023-12-31 00:00:00
#
#       MIN_TEMPERATURE  MAX_TEMPERATURE  MEAN_TEMPERATURE  TOTAL_PRECIPITATION  \
# 0                 1.2              3.1               2.2                  0.0
# ...
